# %%
import pydub
from pydub import AudioSegment

#audio data clips
audio1  = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part1.wav')
audio3  = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part2.wav')
audio5  = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part3.wav')
audio7  = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part4.wav')
audio9  = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part5.wav')
audio11 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part6.wav')
audio13 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part7.wav')
audio15 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part8.wav')
audio17 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part9.wav')
audio19 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part10.wav')
audio21 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part11.wav')
audio23 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Srushti Deshmukh\\Srushti Deshmukh3 part12.wav')
audio25 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Pawan Kalyan\\Pawan Kalyan1 part13.wav')
audio27 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Pawan Kalyan\\Pawan Kalyan1 part14.wav')
audio29 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\ALL SPLIT Pawan Kalyan\\Pawan Kalyan1 part15.wav')


#urban noise clips
audio2 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 1.wav')
audio4 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 2.wav')
audio6 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 3.wav')
audio8 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 4.wav')
audio10 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 5.wav')
audio12 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 6.wav')
audio14 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 7.wav')
audio16 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 8.wav')
audio18 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 9.wav')
audio20 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 10.wav')
audio22 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 5.wav')
audio24 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 2.wav')
audio26 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 9.wav')
audio28 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 10.wav')
audio30 = AudioSegment.from_file('C:\\Users\\Sirisha\\AUDIO\\Raw Data\\Urban new noise\\final mixed audio noise 6.wav')


#overlaping both audio and urban noise
mixed1 = audio1.overlay(audio2)
mixed2 = audio3.overlay(audio4)
mixed3 = audio5.overlay(audio6)
mixed4 = audio7.overlay(audio8)
mixed5 = audio9.overlay(audio10)
mixed6 = audio11.overlay(audio12)
mixed7 = audio13.overlay(audio14)
mixed8 = audio15.overlay(audio16)
mixed9 = audio17.overlay(audio18)
mixed10 = audio19.overlay(audio20)
mixed11 = audio21.overlay(audio22)
mixed12 = audio23.overlay(audio24)
mixed13 = audio25.overlay(audio26)
mixed14 = audio27.overlay(audio28)
mixed15 = audio29.overlay(audio30)

#output in wav file
print(mixed1.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart1.wav", format = "wav"))
print(mixed2.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart2.wav", format = "wav"))
print(mixed3.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart3.wav", format = "wav"))
print(mixed4.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart4.wav", format = "wav"))
print(mixed5.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart5.wav", format = "wav"))
print(mixed6.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart6.wav", format = "wav"))
print(mixed7.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart7.wav", format = "wav"))
print(mixed8.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart8.wav", format = "wav"))
print(mixed9.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart9.wav", format = "wav"))
print(mixed10.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart10.wav", format = "wav"))
print(mixed11.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart11.wav", format = "wav"))
print(mixed12.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart12.wav", format = "wav"))
print(mixed13.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\BR SHAFI\\BR SHAFI7 Npart13.wav", format = "wav"))
print(mixed14.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\BR SHAFI\\BR SHAFI7 Npart14.wav", format = "wav"))
print(mixed15.export("C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\BR SHAFI\\BR SHAFI7 Npart15.wav", format = "wav"))
# Out:
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart1.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart2.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart3.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart4.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart5.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart6.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart7.wav'>
# <_io.BufferedRandom name='C:\\Users\\Sirisha\\AUDIO\\NEW DATA\\Srushti Deshmukh\\Srushti Deshmukh3 Npart8.wav'>
# ...
